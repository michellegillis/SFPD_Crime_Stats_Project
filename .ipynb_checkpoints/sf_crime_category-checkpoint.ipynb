# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

csvpath = "Resources/sfpd_incidents_2016.csv"
sfpd_df = pd.read_csv(csvpath)
sfpd_clean = sfpd_df.loc[sfpd_df['Category']!= 'NON-CRIMINAL']
sf_clean = sfpd_df[~sfpd_df['Category'].isin(['NON-CRIMINAL', 'OTHER OFFENSES','SECONDARY CODES','WARRANTS','SUICIDE','BRIBERY','EXTORTION','EXTORTION','FAMILY OFFENSES','LOITERING','SEX OFFENSES', 'NON FORCIBLE','BAD CHECKS','GAMBLING','PORNOGRAPHY/OBSCENE MAT','TREA'])]
sfpd_clean_df = sfpd_clean.dropna(how='any')
sfpd_rawdata_clean = sfpd_clean_df.drop(['PdId'], axis = 1)
sfpd_rawdata_clean
# Out:
#         IncidntNum         Category  \
# 0        120058272      WEAPON LAWS
# 1        120058272      WEAPON LAWS
# 2        141059263         WARRANTS
# 5        160002869          ASSAULT
# 6        160003130   OTHER OFFENSES
# ...            ...              ...
# 150494   170302853  SECONDARY CODES
# 150495   161061000          ASSAULT
# 150497   176000758    LARCENY/THEFT
# 150498   176000764    LARCENY/THEFT
# 150499   179002868   OTHER OFFENSES
#
#                                                  Descript DayOfWeek  \
# 0                               POSS OF PROHIBITED WEAPON    Friday
# 1          FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# 2                                          WARRANT ARREST    Monday
# 5                                                 BATTERY    Friday
# 6                                        PAROLE VIOLATION  Saturday
# ...                                                   ...       ...
# 150494                                  DOMESTIC VIOLENCE  Thursday
# 150495                                            BATTERY    Friday
# 150497                            PETTY THEFT OF PROPERTY  Thursday
# 150498                            GRAND THEFT OF PROPERTY    Friday
# 150499  FRAUDULENT GAME OR TRICK, OBTAINING MONEY OR P...    Friday
#
#                           Date   Time PdDistrict      Resolution  \
# 0       01/29/2016 12:00:00 AM  11:00   SOUTHERN  ARREST, BOOKED
# 1       01/29/2016 12:00:00 AM  11:00   SOUTHERN  ARREST, BOOKED
# 2       04/25/2016 12:00:00 AM  14:59    BAYVIEW  ARREST, BOOKED
# 5       01/01/2016 12:00:00 AM  21:35   NORTHERN            NONE
# 6       01/02/2016 12:00:00 AM  00:04   SOUTHERN  ARREST, BOOKED
# ...                        ...    ...        ...             ...
# 150494  09/01/2016 12:00:00 AM  00:01    BAYVIEW            NONE
# 150495  12/30/2016 12:00:00 AM  21:01       PARK            NONE
# 150497  12/29/2016 12:00:00 AM  20:00    CENTRAL            NONE
# 150498  12/30/2016 12:00:00 AM  10:00    CENTRAL            NONE
# 150499  12/02/2016 12:00:00 AM  14:00   SOUTHERN            NONE
#
#                          Address           X          Y  \
# 0         800 Block of BRYANT ST -122.403405  37.775421
# 1         800 Block of BRYANT ST -122.403405  37.775421
# 2          KEITH ST / SHAFTER AV -122.388856  37.729981
# 5          1700 Block of BUSH ST -122.426077  37.788019
# 6            MARY ST / HOWARD ST -122.405721  37.780879
# ...                          ...         ...        ...
# 150494     1600 Block of 25TH ST -122.395082  37.752452
# 150495       OAK ST / STANYAN ST -122.453982  37.771428
# 150497       PINE ST / TAYLOR ST -122.412269  37.790673
# 150498  200 Block of STOCKTON ST -122.406659  37.788275
# 150499    800 Block of BRYANT ST -122.403405  37.775421
#
#                                      Location
# 0        (37.775420706711, -122.403404791479)
# 1        (37.775420706711, -122.403404791479)
# 2       (37.7299809672996, -122.388856204292)
# 5        (37.788018555829, -122.426077177375)
# 6       (37.7808789360214, -122.405721454567)
# ...                                       ...
# 150494  (37.7524520499536, -122.395081830837)
# 150495  (37.7714278595913, -122.453981622365)
# 150497   (37.7906727649886, -122.41226909106)
# 150498  (37.7882745285785, -122.406658711008)
# 150499   (37.775420706711, -122.403404791479)
#
# [132633 rows x 12 columns]

# %%
# sub category for other offenses (Raquel)
#combine categoris to streamline (Jordan)
#quarterly breakdown of crimes (Michelle)

# %%
pd.to_datetime(sfpd_rawdata_clean['Date'])
# Out:
# 0        2016-01-29
# 1        2016-01-29
# 2        2016-04-25
# 5        2016-01-01
# 6        2016-01-02
#             ...
# 150494   2016-09-01
# 150495   2016-12-30
# 150497   2016-12-29
# 150498   2016-12-30
# 150499   2016-12-02
# Name: Date, Length: 132633, dtype: datetime64[ns]

# %%
sorted_dates = sfpd_rawdata_clean.sort_values(["Date"], ascending=True)
sorted_dates
# Out:
#         IncidntNum                     Category  \
# 9861     160002580                      ROBBERY
# 9863     160002615                    VANDALISM
# 9862     160002596                     TRESPASS
# 32782    160005023               OTHER OFFENSES
# 22059    160006667                LARCENY/THEFT
# ...            ...                          ...
# 111470   161061674               OTHER OFFENSES
# 111469   161061668                LARCENY/THEFT
# 111467   161061630               OTHER OFFENSES
# 111484   161061793                     WARRANTS
# 19116    170000198  DRIVING UNDER THE INFLUENCE
#
#                                           Descript DayOfWeek  \
# 9861              ROBBERY ON THE STREET, STRONGARM    Friday
# 9863                 MALICIOUS MISCHIEF, VANDALISM    Friday
# 9862                                   TRESPASSING    Friday
# 32782                    LOST/STOLEN LICENSE PLATE    Friday
# 22059               PETTY THEFT FROM UNLOCKED AUTO    Friday
# ...                                            ...       ...
# 111470       DRIVERS LICENSE, SUSPENDED OR REVOKED  Saturday
# 111469                 PETTY THEFT FROM A BUILDING  Saturday
# 111467                POSSESSION OF BURGLARY TOOLS  Saturday
# 111484             ENROUTE TO OUTSIDE JURISDICTION  Saturday
# 19116   DRIVING WHILE UNDER THE INFLUENCE OF DRUGS  Saturday
#
#                           Date   Time PdDistrict      Resolution  \
# 9861    01/01/2016 12:00:00 AM  19:05    CENTRAL            NONE
# 9863    01/01/2016 12:00:00 AM  19:40    CENTRAL            NONE
# 9862    01/01/2016 12:00:00 AM  18:57   SOUTHERN  ARREST, BOOKED
# 32782   01/01/2016 12:00:00 AM  18:00    MISSION            NONE
# 22059   01/01/2016 12:00:00 AM  18:00   RICHMOND            NONE
# ...                        ...    ...        ...             ...
# 111470  12/31/2016 12:00:00 AM  06:41    MISSION  ARREST, BOOKED
# 111469  12/31/2016 12:00:00 AM  06:10   NORTHERN            NONE
# 111467  12/31/2016 12:00:00 AM  05:34   SOUTHERN  ARREST, BOOKED
# 111484  12/31/2016 12:00:00 AM  07:18   NORTHERN  ARREST, BOOKED
# 19116   12/31/2016 12:00:00 AM  23:58    MISSION  ARREST, BOOKED
#
#                            Address           X          Y  \
# 9861           POST ST / TAYLOR ST -122.411702  37.787872
# 9863       700 Block of PACIFIC AV -122.408015  37.796700
# 9862    100 Block of HENRYADAMS ST -122.403885  37.767938
# 32782        20TH ST / HARRISON ST -122.412503  37.759027
# 22059      PINE ST / DIVISADERO ST -122.440252  37.787112
# ...                            ...         ...        ...
# 111470            NOE ST / 18TH ST -122.432795  37.761020
# 111469   2100 Block of BUCHANAN ST -122.430714  37.789789
# 111467     1200 Block of FOLSOM ST -122.410900  37.774408
# 111484  1800 Block of JEFFERSON ST -122.442964  37.804688
# 19116      2200 Block of BRYANT ST -122.409770  37.758817
#
#                                      Location
# 9861    (37.7878718776438, -122.411702003165)
# 9863     (37.796699717573, -122.408014703843)
# 9862    (37.7679376011529, -122.403884601049)
# 32782   (37.7590272974496, -122.412502863675)
# 22059   (37.7871116041945, -122.440251575291)
# ...                                       ...
# 111470  (37.7610201697083, -122.432795347224)
# 111469  (37.7897885529974, -122.430714047833)
# 111467  (37.7744077759133, -122.410900108267)
# 111484   (37.8046876171455, -122.44296385416)
# 19116   (37.7588168712302, -122.409769737777)
#
# [132633 rows x 12 columns]

# %%
sfpd_rawdata_clean["Month"] = sfpd_rawdata_clean["Date"].str.rstrip('/').str.split('/').str[0]
sfpd_rawdata_clean
# Out:
#         IncidntNum         Category  \
# 0        120058272      WEAPON LAWS
# 1        120058272      WEAPON LAWS
# 2        141059263         WARRANTS
# 5        160002869          ASSAULT
# 6        160003130   OTHER OFFENSES
# ...            ...              ...
# 150494   170302853  SECONDARY CODES
# 150495   161061000          ASSAULT
# 150497   176000758    LARCENY/THEFT
# 150498   176000764    LARCENY/THEFT
# 150499   179002868   OTHER OFFENSES
#
#                                                  Descript DayOfWeek  \
# 0                               POSS OF PROHIBITED WEAPON    Friday
# 1          FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# 2                                          WARRANT ARREST    Monday
# 5                                                 BATTERY    Friday
# 6                                        PAROLE VIOLATION  Saturday
# ...                                                   ...       ...
# 150494                                  DOMESTIC VIOLENCE  Thursday
# 150495                                            BATTERY    Friday
# 150497                            PETTY THEFT OF PROPERTY  Thursday
# 150498                            GRAND THEFT OF PROPERTY    Friday
# 150499  FRAUDULENT GAME OR TRICK, OBTAINING MONEY OR P...    Friday
#
#                           Date   Time PdDistrict      Resolution  \
# 0       01/29/2016 12:00:00 AM  11:00   SOUTHERN  ARREST, BOOKED
# 1       01/29/2016 12:00:00 AM  11:00   SOUTHERN  ARREST, BOOKED
# 2       04/25/2016 12:00:00 AM  14:59    BAYVIEW  ARREST, BOOKED
# 5       01/01/2016 12:00:00 AM  21:35   NORTHERN            NONE
# 6       01/02/2016 12:00:00 AM  00:04   SOUTHERN  ARREST, BOOKED
# ...                        ...    ...        ...             ...
# 150494  09/01/2016 12:00:00 AM  00:01    BAYVIEW            NONE
# 150495  12/30/2016 12:00:00 AM  21:01       PARK            NONE
# 150497  12/29/2016 12:00:00 AM  20:00    CENTRAL            NONE
# 150498  12/30/2016 12:00:00 AM  10:00    CENTRAL            NONE
# 150499  12/02/2016 12:00:00 AM  14:00   SOUTHERN            NONE
#
#                          Address           X          Y  \
# 0         800 Block of BRYANT ST -122.403405  37.775421
# 1         800 Block of BRYANT ST -122.403405  37.775421
# 2          KEITH ST / SHAFTER AV -122.388856  37.729981
# 5          1700 Block of BUSH ST -122.426077  37.788019
# 6            MARY ST / HOWARD ST -122.405721  37.780879
# ...                          ...         ...        ...
# 150494     1600 Block of 25TH ST -122.395082  37.752452
# 150495       OAK ST / STANYAN ST -122.453982  37.771428
# 150497       PINE ST / TAYLOR ST -122.412269  37.790673
# 150498  200 Block of STOCKTON ST -122.406659  37.788275
# 150499    800 Block of BRYANT ST -122.403405  37.775421
#
#                                      Location Month
# 0        (37.775420706711, -122.403404791479)    01
# 1        (37.775420706711, -122.403404791479)    01
# 2       (37.7299809672996, -122.388856204292)    04
# 5        (37.788018555829, -122.426077177375)    01
# 6       (37.7808789360214, -122.405721454567)    01
# ...                                       ...   ...
# 150494  (37.7524520499536, -122.395081830837)    09
# 150495  (37.7714278595913, -122.453981622365)    12
# 150497   (37.7906727649886, -122.41226909106)    12
# 150498  (37.7882745285785, -122.406658711008)    12
# 150499   (37.775420706711, -122.403404791479)    12
#
# [132633 rows x 13 columns]

# %%
month_data = sfpd_rawdata_clean[['Month','Category']]
month_datagroup = month_data.groupby(['Month']).count()
month_datagroup
# Out:
#        Category
# Month
# 01        11451
# 02        10607
# 03        10790
# 04        10665
# 05        11105
# 06        10644
# 07        10715
# 08        11056
# 09        10978
# 10        11836
# 11        11336
# 12        11450

# %%
crime = month_datagroup['Category']
month = ['Jan','Feb','March','April','May','June','July','Aug','Sept','Oct','Nov','Dec']
x = np.arange(len(month))
plt.bar(x, crime, color="b", align="center")
tick_locations = [value for value in x]
plt.xticks(tick_locations, month, rotation='vertical')
plt.xlabel('Month')
plt.ylabel('Recorded Offenses')
plt.title('Recorded Offenses per Month')
# Out:
# Text(0.5, 1.0, 'Recorded Offenses per Month')

# %%
day_data = sfpd_rawdata_clean[['DayOfWeek','Category']]
day_datagroup = day_data.groupby(['DayOfWeek']).count()
day_datagroup
# Out:
#            Category
# DayOfWeek
# Friday        20489
# Monday        18379
# Saturday      19450
# Sunday        17765
# Thursday      18874
# Tuesday       18814
# Wednesday     18862

# %%
crime = day_datagroup['Category']
day = ['Friday','Monday','Saturday','Sunday','Thursday','Tuesday','Wednesday']
x_axis = np.arange(len(day))
plt.bar(x_axis, crime, color="b", align="center")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, day, rotation='vertical')
plt.xlabel('Day of the Week')
plt.ylabel('Recorded Offenses')
plt.title('Recorded Offenses per Day of the Week')
# Out:
# 21532

# %%
incident_df = sfpd_rawdata_clean[['IncidntNum', 'Category']]
groupedincidents = incident_df.groupby(['IncidntNum']).count()
multoffense = groupedincidents.loc[groupedincidents['Category']>1]
multoffense['Category'].count()
# Out:
# 21532
