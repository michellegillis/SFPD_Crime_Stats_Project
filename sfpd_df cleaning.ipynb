# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import csv

csvpath = "Resources/sfpd_incidents_2016.csv"
sfpd_df = pd.read_csv(csvpath)
sfpd_clean = sfpd_df.loc[sfpd_df['Category']!= 'NON-CRIMINAL']
sfpd_clean_df = sfpd_clean.dropna(how='any')
sfpd_rawdata_clean = sfpd_clean_df.drop(['PdId'], axis = 1)
sfpd_rawdata_clean
# Out:
#         IncidntNum         Category  \
# 0        120058272      WEAPON LAWS
# 1        120058272      WEAPON LAWS
# 2        141059263         WARRANTS
# 5        160002869          ASSAULT
# 6        160003130   OTHER OFFENSES
# ...            ...              ...
# 150494   170302853  SECONDARY CODES
# 150495   161061000          ASSAULT
# 150497   176000758    LARCENY/THEFT
# 150498   176000764    LARCENY/THEFT
# 150499   179002868   OTHER OFFENSES
#
#                                                  Descript DayOfWeek  \
# 0                               POSS OF PROHIBITED WEAPON    Friday
# 1          FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# 2                                          WARRANT ARREST    Monday
# 5                                                 BATTERY    Friday
# 6                                        PAROLE VIOLATION  Saturday
# ...                                                   ...       ...
# ...

# %%
#create subcategories for Other Offenses
#create overall chart showing crime types across the entire city
#heat map showing crime by location

# %%
sfpd_rawdata_clean["Category"].value_counts()
# Out:
# LARCENY/THEFT                  40408
# OTHER OFFENSES                 19599
# ASSAULT                        13577
# VANDALISM                       8589
# VEHICLE THEFT                   6419
# WARRANTS                        5914
# BURGLARY                        5802
# SUSPICIOUS OCC                  5782
# MISSING PERSON                  4338
# DRUG/NARCOTIC                   4243
# ROBBERY                         3299
# FRAUD                           2635
# SECONDARY CODES                 1841
# TRESPASS                        1812
# WEAPON LAWS                     1658
# SEX OFFENSES, FORCIBLE           940
# STOLEN PROPERTY                  882
# RECOVERED VEHICLE                736
# DISORDERLY CONDUCT               658
# PROSTITUTION                     641
# FORGERY/COUNTERFEITING           619
# DRUNKENNESS                      465
# DRIVING UNDER THE INFLUENCE      378
# ARSON                            286
# KIDNAPPING                       257
# ...

# %%
sfpd_incnum = sfpd_rawdata_clean.drop_duplicates(subset = "IncidntNum")
sfpd_incnum
# Out:
#         IncidntNum        Category  \
# 0        120058272     WEAPON LAWS
# 2        141059263        WARRANTS
# 5        160002869         ASSAULT
# 6        160003130  OTHER OFFENSES
# 8        160003970        WARRANTS
# ...            ...             ...
# 150493   160858327         ASSAULT
# 150495   161061000         ASSAULT
# 150497   176000758   LARCENY/THEFT
# 150498   176000764   LARCENY/THEFT
# 150499   179002868  OTHER OFFENSES
#
#                                                  Descript DayOfWeek  \
# 0                               POSS OF PROHIBITED WEAPON    Friday
# 2                                          WARRANT ARREST    Monday
# 5                                                 BATTERY    Friday
# 6                                        PAROLE VIOLATION  Saturday
# 8                                          WARRANT ARREST  Saturday
# ...                                                   ...       ...
# ...

# %%
sfpd_rawdata_clean2  = sfpd_rawdata_clean.set_index("IncidntNum")
sfpd_rawdata_clean2.head()
# Out:
#                   Category                                        Descript  \
# IncidntNum
# 120058272      WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 120058272      WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 141059263         WARRANTS                                  WARRANT ARREST
# 160002869          ASSAULT                                         BATTERY
# 160003130   OTHER OFFENSES                                PAROLE VIOLATION
#
#            DayOfWeek                    Date   Time PdDistrict  \
# IncidntNum
# 120058272     Friday  01/29/2016 12:00:00 AM  11:00   SOUTHERN
# 120058272     Friday  01/29/2016 12:00:00 AM  11:00   SOUTHERN
# 141059263     Monday  04/25/2016 12:00:00 AM  14:59    BAYVIEW
# 160002869     Friday  01/01/2016 12:00:00 AM  21:35   NORTHERN
# 160003130   Saturday  01/02/2016 12:00:00 AM  00:04   SOUTHERN
#
#                 Resolution                 Address           X          Y  \
# IncidntNum
# ...

# %%
sfpd_incnum["PdDistrict"].value_counts()
# Out:
# SOUTHERN      19427
# NORTHERN      14340
# MISSION       12662
# CENTRAL       12493
# BAYVIEW        9894
# INGLESIDE      7725
# TARAVAL        7688
# RICHMOND       6323
# TENDERLOIN     5904
# PARK           5820
# Name: PdDistrict, dtype: int64

# %%
sfpd_rawdata_clean2.Location[sfpd_rawdata_clean2.PdDistrict.isnull()]

# %%
# make index by indicentNum 
# drop non-criminal indidents
# count only criminal incidents 
# count/group criminal incedents by districts 
# group/count the criminal incedents by addresses
# type of criminal incidents by distric

# %%
sfpd_rawdata_clean2.loc[["SOUTHERN", "NORTHERN", "MISSION", "CENTRAL", "BAYVIEW", "INGLESIDE",
                         "TARAVAL","TENDERLOIN", "RICHMOND", "PARK"],["PdDistrict", "IncidntNum"]]

# %%
sfpd_rawdata_clean2["IncidntNum"].value_counts() ["IncidntNum"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'IncidntNum'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-3be0f6d687f0> in <module>
# ...
